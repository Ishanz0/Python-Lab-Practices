# %%
d={}
d["apple"]=10
d["banana"]=20
d["kiwi"]=30
d["mango"]=40

# %%
n=1
bill=0
while(n):
  order=input("enter order :")
  q=int(input("enter quan :"))
  con=int(input("1 to confirm"))
  if(con==1):
    bill+=d[order]*q
  n=int(input("enter 1 to buy 0 to break "))
print(bill)
# Out:
# enter order :apple
# enter quan :5
# 1 to confirm1
# enter 1 to buy 0 to break 0
# 50

# %%
d={}
d["apple"]=1
d["banana"]=2
d["Kiwi"]=3
d["Mango"]=4

print("menu is :")
for i,j in d.items():
  print(i,j)

n=1
bill=0
while(n):
  order=input("enter order :")
  q=int(input("enter quantity :"))
  con=int(input("1 to confirm :"))
  if(con==1):
    bill+=d[order]*q
  n=int(input("enter 1 to buy again, 0 to checkout :"))
print(bill)
# Out:
# menu is :
# apple 1
# banana 2
# Kiwi 3
# Mango 4
# enter order :apple
# enter quantity :5
# 1 to confirm :1
# enter 1 to buy again, 0 to checkout :0
# 5

# %%
d={}
d["apple"]=10
d["banana"]=20
d["kiwi"]=30
d["mango"]=40

print("menu is :")
for i,j in d.items():
  print(i,j)

n=1
bill=0
while(n):
  order=input("enter order :")
  q=int(input("enter quantity :"))
  con=int(input("1 to confirm 2 to modify :"))
  if(con==1):
    bill+=d[order]*q
  else:
    a=int(input("Enter for 1 for qun 2, for new item,3 remove"))
    if(a==1):
      q=int(input("enter quantity :"))
    elif (a==2):
      order=input("enter order :")
    elif(a==3):
      order=input("enter remove order :")
      bill=bill-d[order]
    else:
      print("Ivalid")

  n=int(input("enter 1 to buy again, 0 to checkout :"))
print(bill)
# Out:
# menu is :
# apple 10
# banana 20
# kiwi 30
# mango 40
# enter order :kiwi
# enter quantity :4
# 1 to confirm 2 to modify :2
# Enter for 1 for qun 2, for new item,3 remove2
# enter order :apple
# enter 1 to buy again, 0 to checkout :0
# 0

# %%
asp=open("az.txt","r")
d=asp.read()

l=d.split()

words=0

words=words+len(l)

words

a=dict()

for ls in l:
  if ls in a:
    a[ls] = a[ls] + 1
  else:
    a[ls] = 1

#print(a)

for key in list(a.keys()):
  print(key, ":" , a[key])

asp1=open("ax.txt","r")
n=asp1.read()

b=n.split()

w = 0

w = w + len(b)

w

s = dict()

for la in b:
  if la in s:
    s[la] = s[la] + 1
  else:
    s[la] = 1

for k in list(s.keys()):
  print(k, ":" , s[k])





temp=[]

for key,val in a.items():
  if key not in temp:
    temp.append(key)
temp

temp1=[]

for key1,val1 in s.items():
  if key1 not in temp1:
    temp1.append(key1)
temp1

z=0
for g in temp:
  for y in temp1:
    if(g == y):
      z=z+1
print(z)

len(a)

len(s)

c=z/len(s)*100
c
# Out:
# {'Musk': 4, 'took': 2, 'an': 1, 'active': 1, 'role': 1, 'within': 1, 'the': 13, 'company': 3, 'and': 5, 'oversaw': 1, 'Roadster': 1, 'product': 1, 'design': 1, 'at': 4, 'a': 3, 'detailed': 1, 'level,': 1, 'but': 1, 'was': 4, 'not': 1, 'deeply': 1, 'involved': 1, 'in': 7, 'day-to-day': 1, 'business': 1, 'operations.[16]': 1, 'From': 1, 'beginning,': 1, 'consistently': 1, 'maintained': 1, 'that': 1, "Tesla's": 3, 'long-term': 1, 'goal': 1, 'to': 6, 'create': 1, 'affordable': 2, 'mass': 1, 'market': 1, 'electric': 1, 'vehicles.[17]': 1, 'The': 1, "company's": 1, 'strategy': 1, 'start': 1, 'with': 1, 'premium': 1, 'sports': 1, 'car': 1, 'aimed': 1, 'early': 1, 'adopters': 1, 'then': 2, 'move': 1, 'into': 1, 'more': 1, 'mainstream': 1, 'vehicles,': 1, 'including': 2, 'sedans': 1, 'compacts.[18]': 1, 'In': 2, 'February': 1, '2006,': 2, 'led': 2, 'Series': 1, 'B': 1, 'venture': 1, 'capital': 1, 'funding': 2, 'round': 3, 'of': 6, '$13': 1, 'million,': 1, 'which': 2, 'added': 1, 'Valor': 1, '
# ...
